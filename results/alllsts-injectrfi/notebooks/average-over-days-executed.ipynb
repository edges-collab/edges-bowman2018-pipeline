# %% [markdown]
# # Average Multiple Days Together

# %% [markdown]
# ## Imports and Versions

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from typing import Literal
from astropy import units as u
from scipy.stats import norm

from pygsdata import GSData, plots, GSFlag
from pygsdata.register import gsregister

from edges import modeling as mdl
from edges.averaging import average_over_times, NsamplesStrategy, get_weights_from_strategy
from edges.analysis.datamodel import add_model
from edges.filters import rfi_model_filter
from edges.alanmode import read_spec_txt
from edges.filters import filters
from edges.filters.filters import gsdata_filter
from edges.averaging import averaging

from edges_pipeline_utils import utils

# %%
plt.style.use("default")

# %%
utils.print_versions()
# Out:
# Versions:
#             read_acq: 1.2.0
#             pygsdata: 0.2.3
#       edges-analysis: 8.1.0

# %% [markdown]
# ## Parameters and Data Loading

# %%
gathered_days_file: str = "gathered-days.gsh5"
alandir: str = "/home/smurray/data4/edges/alans-pipeline/scripts/H2CaseFieldData/"

do_rfi_round_2: bool = True
do_rfi_round_3: bool = True
raise_unmatching: bool = True
compare_alan: bool = True

# %%
# Parameters
raise_unmatching = False
compare_alan = False
gathered_days_file = "/data7/smurray/edges/projects_with_nive/edges-bowman2018-pipeline/work/69/facb6f5f2e46d6df3a1870067100c8/gathered-days.gsh5"

# %%
gathered_days_file = Path(gathered_days_file)

# %%
data = GSData.from_file(gathered_days_file)

# %% [markdown]
# ## Analysis and Averaging

# %% [markdown]
# ### Model the spectra so we can average residuals only

# %% [markdown]
# When we perform the average over nights, we average the models and residuals separately (and the residuals receive frequency-dependent weights while the models do not). First, we model each night here.

# %%
data = add_model(data, model=mdl.models.PhysicalIono(spectral_index=-2.55, f_center=75.0, n_terms=5), nsamples_strategy=NsamplesStrategy.FLAGGED_NSAMPLES_UNIFORM)

# %%
alanmodel = np.genfromtxt("/home/smurray/data4/edges/alans-pipeline/scripts/nightly_model_file.txt")

# %%
alan_dates = np.genfromtxt("/home/smurray/data4/edges/alans-pipeline/scripts/nightly_dates.txt")

# %%
alan_data = np.genfromtxt("/home/smurray/data4/edges/alans-pipeline/scripts/nightly_data.txt")

# %%
for i in range(data.ntimes):
    plt.plot(data.freqs, data.model[0,0,i] - alanmodel[i])
plt.xlabel("Frequency [MHz]")
plt.ylabel("Model Difference [K]")
plt.title("Difference in night-to-night models between edges-analysis and C-code")
# Out:
# Text(0.5, 1.0, 'Difference in night-to-night models between edges-analysis and C-code')

# %% [markdown]
# ### Some Filters

# %% [markdown]
# Our first filter is an RMS filter (just thresholding a whole night based on its RMS to the fitted model)

# %%
alanfilt = np.genfromtxt("/home/smurray/data4/edges/alans-pipeline/scripts/nightly_flagfile.txt")

# %%
alflags = GSFlag(~(alanfilt[:, 1].astype(bool)), axes=("time",))

# %%
rms_data = filters.rms_filter(data, threshold=0.17, nsamples_strategy=NsamplesStrategy.FLAGGED_NSAMPLES_UNIFORM) 
rms_data_alan =  data.add_flags(flags=alflags, filt='applying Alans RMS filter flags')

# %%
if raise_unmatching:
    assert np.sum(~rms_data.flags['rms_filter'].flags[0,0] ^ alanfilt[:, 1].astype(bool))==0
elif compare_alan:
    print("Unmatched flags: ", np.sum(~rms_data.flags['rms_filter'].flags[0,0] ^ alanfilt[:, 1].astype(bool)))

# %%
rms_data = filters.prune_flagged_integrations(rms_data)
rms_data_alan = filters.prune_flagged_integrations(rms_data_alan)

# %%
print(rms_data.ntimes, rms_data_alan.ntimes)
# Out:
# 64 62

# %% [markdown]
# Based on the model already fit, we perform simple RFI-flagging, where we flag any channel whose residual is larger than a threshold multiplied by the RMS of the residuals that night (over frequency).

# %%
rms_data.write_gsh5("filtered-gathered-data.gsh5")
# Out:
# GSData(telescope=Telescope(name='edges-low-alan', location=<EarthLocation (-2544175.08852437, 5102825.79106231, -2848558.83597113) m>, pols=('XX',), integration_time=<Quantity 13. s>, x_orientation=<Angle 0. deg>), data=array([[[[4932.23765481, 4836.29777235, 4743.56098253, ...,
#            871.41497919,  862.9917109 ,  853.8548333 ],
#          [4951.51898131, 4855.49493484, 4761.90686863, ...,
#            873.59688486,  865.26552383,  856.63910277],
#          [4941.4985381 , 4845.11224655, 4751.94195188, ...,
#            872.4987144 ,  864.05195727,  854.89359358],
#          ...,
#          [4675.30267728, 4583.48575305, 4494.18208081, ...,
#            809.47073566,  801.42596694,  792.56329854],
#          [4971.31068883, 4874.13547762, 4778.02047202, ...,
#            867.02256907,  858.15273984,  849.78856831],
#          [4959.33368275, 4863.54034236, 4766.50613046, ...,
#            866.68170505,  857.75364517,  849.06394348]]]],
#       shape=(1, 1, 64, 128)), freqs=<Quantity [50.01220703, 50.40283203, 50.79345703, 51.18408203, 51.57470703,
#            51.96533203, 52.35595703, 52.74658203, 53.13720703, 53.52783203,
#            53.91845703, 54.30908203, 54.69970703, 55.09033203, 55.48095703,
#            55.87158203, 56.26220703, 56.65283203, 57.04345703, 57.43408203,
#            57.82470703, 58.21533203, 58.60595703, 58.99658203, 59.38720703,
#            59.77783203, 60.16845703, 60.55908203, 60.94970703, 61.34033203,
#            61.73095703, 62.12158203, 62.51220703, 62.90283203, 63.29345703,
#            63.68408203, 64.07470703, 64.46533203, 64.85595703, 65.24658203,
#            65.63720703, 66.02783203, 66.41845703, 66.80908203, 67.19970703,
#            67.59033203, 67.98095703, 68.37158203, 68.76220703, 69.15283203,
#            69.54345703, 69.93408203, 70.32470703, 70.71533203, 71.10595703,
#            71.49658203, 71.88720703, 72.27783203, 72.66845703, 73.05908203,
#            73.44970703, 73.84033203, 74.23095703, 74.62158203, 75.01220703,
#            75.40283203, 75.79345703, 76.18408203, 76.57470703, 76.96533203,
#            77.35595703, 77.74658203, 78.13720703, 78.52783203, 78.91845703,
#            79.30908203, 79.69970703, 80.09033203, 80.48095703, 80.87158203,
#            81.26220703, 81.65283203, 82.04345703, 82.43408203, 82.82470703,
#            83.21533203, 83.60595703, 83.99658203, 84.38720703, 84.77783203,
#            85.16845703, 85.55908203, 85.94970703, 86.34033203, 86.73095703,
#            87.12158203, 87.51220703, 87.90283203, 88.29345703, 88.68408203,
#            89.07470703, 89.46533203, 89.85595703, 90.24658203, 90.63720703,
#            91.02783203, 91.41845703, 91.80908203, 92.19970703, 92.59033203,
#            92.98095703, 93.37158203, 93.76220703, 94.15283203, 94.54345703,
#            94.93408203, 95.32470703, 95.71533203, 96.10595703, 96.49658203,
#            96.88720703, 97.27783203, 97.66845703, 98.05908203, 98.44970703,
#         AAAAAAAAKgAAAAAAAAArAAAAAAAAACwAAAAAAAAAMAAAAAAAAAAxAAAAAAAAADMAAAAAAAAANAAA
#         AAAAAAA2AAAAAAAAADgAAAAAAAAAOQAAAAAAAAA7AAAAAAAAAD0AAAAAAAAAPgAAAAAAAABAAAAA
#         AAAAAEEAAAAAAAAARAAAAAAAAABGAAAAAAAAAEoAAAAAAAAASwAAAAAAAABNAAAAAAAAAE4AAAAA
#         AAAATwAAAAAAAABSAAAAAAAAAFMAAAAAAAAAVAAAAAAAAABVAAAAAAAAAFYAAAAAAAAAVwAAAAAA
#         AABYAAAAAAAAAFoAAAAAAAAAWwAAAAAAAABdAAAAAAAAAF4AAAAAAAAAXwAAAAAAAABgAAAAAAAA
#         AGEAAAAAAAAAYgAAAAAAAABjAAAAAAAAAGQAAAAAAAAAZQAAAAAAAABmAAAAAAAAAGgAAAAAAAAA
#         agAAAAAAAABuAAAAAAAAAG8AAAAAAAAAcAAAAAAAAABxAAAAAAAAAHMAAAAAAAAAdAAAAAAAAAA=
#   timestamp: '2025-12-11T11:43:44.131410'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# , filename=None)}, history=!!python/tuple
# - function: read_acq_to_gsdata
#   message: Read from ACQ file
#   parameters:
#     path:
#     - 'tag:yaml.org,2002:python/object/apply:pathlib.PosixPath: [ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''/''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''data5''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''edges''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''data''),
#       ScalarNode(tag=''tag:yaml.org,2002:str'', value=''2014_February_Boolardy''),
#       ScalarNode(tag=''tag:yaml.org,2002:str'', value=''mro''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''low''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''2016''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''2016_250_02.acq'')]'
#   timestamp: '2025-09-19T16:46:31.432746'
#   versions:
#     astropy: 7.1.0
#     numpy: 2.3.2
#     pygsdata: 0.2.3
# - function: select_lsts
#   message: ''
#   parameters:
#     gha: true
#     load: all
#     lst_range:
#     - 6.0
#     - 18.0
#   timestamp: '2025-11-17T11:58:19.286687'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: aux_filter
#   message: ''
#   parameters:
#     maxima:
#       adcmax: 0.35
#     minima: {}
#   timestamp: '2025-11-17T11:58:21.847257'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: power_percent_filter
#   message: ''
#   parameters:
#     max_threshold: 3
#     min_threshold: 0.7
#   timestamp: '2025-11-17T11:58:56.471020'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: dicke_calibration
#   message: ''
#   parameters: {}
#   timestamp: '2025-11-17T11:58:57.250526'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: approximate_temperature
#   message: ''
#   parameters:
#     tload: 300
#     tns: 1000
#   timestamp: '2025-11-17T11:58:57.456138'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: peak_orbcomm_filter
#   message: ''
#   parameters:
#     threshold: 40.0
#   timestamp: '2025-11-17T11:58:59.851752'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: maxfm_filter
#   message: ''
#   parameters:
#     threshold: 200.0
#   timestamp: '2025-11-17T11:59:01.272255'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: rmsf_filter
#   message: ''
#   parameters:
#     freq_range:
#     - 60.0
#     - 80.0
#     threshold: 200.0
#   timestamp: '2025-11-17T11:59:02.573930'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: average_over_times
#   message: ''
#   parameters:
#     nsamples_strategy: 'tag:yaml.org,2002:python/object/apply:edges.averaging.utils.NsamplesStrategy:
#       [ScalarNode(tag=''tag:yaml.org,2002:int'', value=''2'')]'
#     reference_lst: "tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:\
#       \ [(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.coordinates.angles.core.Longitude',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='0')]), ScalarNode(tag='tag:yaml.org,2002:binary', value='Yg==\\n')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='state'), SequenceNode(tag='tag:yaml.org,2002:python/tuple',\
#       \ value=[SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1'), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[]),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object/apply:numpy.dtype', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='args'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='f8'), ScalarNode(tag='tag:yaml.org,2002:bool', value='false'), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='3'), ScalarNode(tag='tag:yaml.org,2002:str', value='<'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:null', value='null'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:int', value='-1'), ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='-1'), ScalarNode(tag='tag:yaml.org,2002:int', value='0')]))]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='false'), ScalarNode(tag='tag:yaml.org,2002:binary', value='tI1QRm8LF0A=\\\
#       n')]), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_unit'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.Unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='hour angle: angular measurement with 24 in a full circle')), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_format'), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='latex'), ScalarNode(tag='tag:yaml.org,2002:str', value='{}^{h}')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='unicode'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='\u02B0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_names'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='hourangle')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_represents'),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.Unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree: angular measurement 1/360 of full rotation')), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_format'), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='latex'), ScalarNode(tag='tag:yaml.org,2002:str', value='{}^{\\\\circ}')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='unicode'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='\xB0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg'), ScalarNode(tag='tag:yaml.org,2002:str', value='degree')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_represents'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian: angular\
#       \ measurement of the ratio between the length on an arc\\nand its radius')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_format'), MappingNode(tag='tag:yaml.org,2002:map',\
#       \ value=[])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='radian')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:str', value='rad')]))]))])])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_decomposed_cache'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[...])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_powers'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='0.017453292519943295'))])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg')]))])])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_decomposed_cache'),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian: angular\
#       \ measurement of the ratio between the length on an arc\\nand its radius')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_format'), MappingNode(tag='tag:yaml.org,2002:map',\
#       \ value=[])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='radian')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:str', value='rad')]))]))])])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_powers'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='0.2617993877991494'))])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_powers'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='15.0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='hourangle')]))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_wrap_angle'),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.coordinates.angles.core.Angle',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='0')]), ScalarNode(tag='tag:yaml.org,2002:binary', value='Yg==\\n')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='state'), SequenceNode(tag='tag:yaml.org,2002:python/tuple',\
#       \ value=[SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1'), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[]),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object/apply:numpy.dtype', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='args'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='f8'), ScalarNode(tag='tag:yaml.org,2002:bool', value='false'), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='3'), ScalarNode(tag='tag:yaml.org,2002:str', value='<'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:null', value='null'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:int', value='-1'), ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='-1'), ScalarNode(tag='tag:yaml.org,2002:int', value='0')]))]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='false'), ScalarNode(tag='tag:yaml.org,2002:binary', value='AAAAAACAdkA=\\\
#       n')]), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_unit'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.Unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree: angular measurement 1/360 of full rotation')), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_format'), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='latex'), ScalarNode(tag='tag:yaml.org,2002:str', value='{}^{\\\\circ}')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='unicode'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='\xB0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg'), ScalarNode(tag='tag:yaml.org,2002:str', value='degree')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_represents'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian: angular\
#       \ measurement of the ratio between the length on an arc\\nand its radius')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_format'), MappingNode(tag='tag:yaml.org,2002:map',\
#       \ value=[])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='radian')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:str', value='rad')]))]))])])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_decomposed_cache'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[...])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_powers'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='0.017453292519943295'))])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg')]))]))])]))]))])]))]"
#     use_resids: false
#   timestamp: '2025-11-17T11:59:11.238720'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: select_freqs
#   message: ''
#   parameters:
#     freq_range:
#     - 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:
#       [(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.quantity.Quantity'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''Yg==\n'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[]),
#       MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#       value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#       ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]))]), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''AAAAAAAAREA=\n'')]), MappingNode(tag=''tag:yaml.org,2002:map'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_unit''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.PrefixUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz (MHz)'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''MHz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.Unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Frequency'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''Hz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_decomposed_cache''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[...])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_powers''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hz'')]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_decomposed_cache''),
#       MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''MHz'')]))]))])]))]'
#     - 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:
#       [(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.quantity.Quantity'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''Yg==\n'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[]),
#       MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#       value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#       ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]))]), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''AAAAAAAAWUA=\n'')]), MappingNode(tag=''tag:yaml.org,2002:map'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_unit''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.PrefixUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz (MHz)'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''MHz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.Unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Frequency'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''Hz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_decomposed_cache''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[...])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_powers''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hz'')]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_decomposed_cache''),
#       MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''MHz'')]))]))])]))]'
#   timestamp: '2025-11-17T11:59:11.371944'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: gauss_smooth
#   message: ''
#   parameters:
#     decimate_at: 0
#     flag_threshold: 0.25
#     maintain_flags: 1
#     size: 8
#     use_nsamples: true
#   timestamp: '2025-11-17T11:59:13.036011'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: select_freqs
#   message: ''
#   parameters:
#     freq_range: !!python/tuple
#     - 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:
#       [(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.quantity.Quantity'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''Yg==\n'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[]),
#       MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#       value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#       ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]))]), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''AAAAAAAASUA=\n'')]), MappingNode(tag=''tag:yaml.org,2002:map'',
# ...
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''845'')]), MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'',
#       value=''false''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#       value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#       ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''0'')]))]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''), ScalarNode(tag=''tag:yaml.org,2002:binary'',
#       value=''\n7XkA7z9g ...
#     resample_beam_lsts: true
#   timestamp: '2025-12-11T11:41:27.751158'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: add_model
#   message: ''
#   parameters:
#     model:
#       _transform:
#         scale: 75.0
#       basis_scaler: null
#       data_transform: {}
#       f_center: 75.0
#       n_terms: 3
#       parameters: null
#       spectral_index: -2.5
#       with_cmb: false
#       xtransform:
#         scale: 75.0
#     nsamples_strategy: 'tag:yaml.org,2002:python/object/apply:edges.averaging.utils.NsamplesStrategy:
#       [ScalarNode(tag=''tag:yaml.org,2002:int'', value=''2'')]'
#   timestamp: '2025-12-11T11:41:28.281672'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: gauss_smooth
#   message: ''
#   parameters:
#     decimate_at: 0
#     maintain_flags: 9
#     nsmooth: 2
#     size: 8
#     use_nsamples: false
#     use_residuals: true
#   timestamp: '2025-12-11T11:41:29.024364'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: concat
#   message: ''
#   parameters: {}
#   timestamp: '2025-12-11T11:43:35.125296'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: add_model
#   message: ''
#   parameters:
#     model:
#       _transform:
#         scale: 75.0
#       basis_scaler: null
#       data_transform: {}
#       f_center: 75.0
#       n_terms: 5
#       parameters: null
#       spectral_index: -2.55
#       with_cmb: false
#       xtransform:
#         scale: 75.0
#     nsamples_strategy: &id001 !!python/object/apply:edges.averaging.utils.NsamplesStrategy
#     - 2
#   timestamp: '2025-12-11T11:43:43.730577'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: rms_filter
#   message: ''
#   parameters:
#     nsamples_strategy: *id001
#     threshold: 0.17
#   timestamp: '2025-12-11T11:43:44.067743'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: prune_flagged_integrations
#   message: ''
#   parameters: {}
#   timestamp: '2025-12-11T11:43:44.145749'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# , residuals=array([[[[-0.5931946 , -0.68588067, -0.13488993, ..., -0.23631467,
#            0.06511976, -0.46901331],
#          [ 0.14407025,  0.30974351,  0.35176759, ..., -0.35182843,
#            0.07583686,  0.08619484],
#          [ 0.27615308, -0.20422952, -0.01448675, ..., -0.43050396,
#           -0.14649574, -0.69614147],
#          ...,
#          [-0.82209522, -0.34299426,  0.11197424, ..., -0.34852019,
#           -0.18858675, -0.96275388],
#          [-0.18282999,  0.37270849, -0.69551854, ..., -0.29202407,
#           -0.40903908, -0.1440933 ],
#          [-1.98768758,  0.0347166 , -1.8935188 , ..., -0.07656658,
#           -0.29764588, -0.4037967 ]]]], shape=(1, 1, 64, 128)), data_unit='temperature', auxiliary_measurements=<QTable length=64>
#   adcmax      adcmin
#  float32     float32
# ---------- -----------
#  0.2799319 -0.29045808
#   0.280932 -0.29247674
# 0.28151792  -0.2930776
#  0.2796064 -0.28967217
#  0.2806164  -0.2911678
#  0.2792548 -0.29006344
# 0.28046265  -0.2916572
# 0.27954268 -0.29161188
# 0.28031233 -0.29129082
#        ...         ...
# 0.27380353 -0.28360313
# 0.27398634 -0.28364977
# 0.27072453 -0.28013778
# 0.26932234 -0.27854446
# 0.27077362 -0.28047404
#  0.2700609 -0.27925992
# 0.27045864 -0.27992612
# 0.28174168  -0.2912492
# 0.27249363  -0.2822668
#   0.269335 -0.27873144, time_ranges=<Time object: scale='utc' format='jd' value=[[[2457646.50025463 2457647.4997338 ]]
#
#  [[2457648.50006944 2457649.49990741]]
#
#  [[2457650.50039352 2457651.49979167]]
#
#  [[2457652.50016204 2457653.49929398]]
#
#  [[2457655.50012731 2457656.49971065]]
#
#  [[2457657.50024306 2457658.50009259]]
#
#  [[2457661.15831019 2457661.49975694]]
#
#  [[2457662.50003472 2457663.49997685]]
#
#  [[2457663.50070602 2457664.49945602]]
#             [6.2730234 ],
#             [5.67144017],
#             [4.88642072],
#             [5.71052963],
#             [5.45313234],
#             [5.73447296],
#             [5.62782098],
#             [5.36644993],
#             [3.68473349],
#             [5.67405247],
#             [5.48924661],
#             [4.46834936],
#             [5.75110245],
#             [5.75542935],
#             [5.69876568],
#             [5.17685694],
#             [5.54197598],
#             [5.71515668],
#             [5.73680052],
#             [5.77898358],
#             [5.44394305],
#             [5.77689154],
#             [5.61918762],
#             [5.73725815],
#             [5.77561161],
#             [6.06561135],
#             [5.75171538],
#             [5.66999762],
#             [5.98226056],
#             [5.73634918],
#             [3.10164709],
#             [5.7419791 ],
#             [5.74901433],
#             [5.77604944],
#             [2.63821067],
#             [5.76076192],
#             [5.39539857],
#             [5.62665394],
#             [4.89610471],
#             [5.77454117],
#             [5.21638167]] hourangle>, lst_ranges=<Longitude [[[23.76613132, 11.75611655]],
#
#             [[23.76301697, 11.7493812 ]],
#
#             [[23.76658753, 11.74877369]],
#
#             [[23.76820833, 11.75262279]],
#
#             [[23.76479022, 11.75282568]],
#
#             [[23.76724663, 11.74748302]],
#
#             [[ 0.15517485,  8.37233348]],
#
#             [[23.76433517, 11.75264917]],
#
#             [[23.77127341, 11.74928149]],
#
#             [[23.76937524, 11.75351116]],
#
#             [[23.7634755 , 11.75234658]],
#
#             [[23.76261467, 11.74758621]],
#
#             [[23.7633242 , 11.74996697]],
#
#             [[23.76274191, 11.75133445]],
#
#             [[23.77079431, 11.73988916]],
#
#             [[23.7621344 , 11.72649411]],
#
#             [[23.76183065, 11.7512588 ]],
#
#             [[23.77044012, 11.74705551]],
#
#             [[23.84883663, 11.75219644]],
#
#             [[23.76914945, 11.74743607]],
#
#             [[23.7638836 , 11.75108345]],
#
#             [[23.77082185, 11.74910847]],
#
#             [[23.77021434, 11.75212195]],
#
#             [[23.76180776, 11.75040029]],
#
#             [[23.76930307, 11.75483169]],
#
#             [[23.76618872, 11.74976757]],
#
#             [[23.7669739 , 11.74857777]],
#
#             [[23.76249207, 11.75635162]],
#
#             [[23.76383433, 11.75323727]],
#
#             [[23.77049404, 11.65878757]],
#
#             [[23.77041839, 11.66706807]],
#
#             [[23.7670255 , 11.75698551]],
#
#             [[23.76636756, 11.73738696]],
#
#             [[23.76801357, 11.74933889]],
#
#             [[23.76183529, 10.93679222]],
#
#             [[23.77016623, 11.75177009]],
#
#             [[23.7620634 , 11.74923803]],
#
#             [[23.76588729, 11.75194777]],
#
#             [[23.765305  , 11.74161663]],
#
#             [[23.76806516, 11.75551833]],
#
#             [[23.76943264, 11.75242919]],
#
#             [[23.76160835, 11.75463228]],
#
#             [[23.77551005, 11.75098607]],
#
#             [[23.7679643 , 11.56461873]],
#
#             [[23.76707825, 11.7536958 ]],
#
#             [[23.7631535 , 11.74782128]],
#
#             [[23.76310307, 11.75529139]],
#
#             [[23.77115546, 11.75443056]],
#
#             [[23.78143616, 11.74967019]],
#
#             [[23.76636988, 11.74685959]],
#
#             [[23.76355928, 11.75017683]],
#
#             [[23.76325552, 11.75182285]],
#
#             [[23.76406592, 11.75263325]],
#
#             [[23.76933294,  6.83696397]],
#
#             [[23.76457257, 11.74840474]],
#
#             [[23.7692825 , 11.7525576 ]],
#
#             [[23.76199008, 11.75027886]],
#
#             [[23.76806749,  8.80217897]],
#
#             [[23.76156024, 11.74399972]],
#
#             [[23.76515602, 11.75372334]],
#
#             [[23.76986596, 11.75258397]],
#
#             [[23.83306894, 11.75060899]],
#
#             [[23.76143416, 11.7494444 ]],
#
#             [[23.76892948, 11.7574968 ]]] hourangle>, filename=PosixPath('filtered-gathered-data.gsh5'), _file_appendable=False, name='2016-250')

# %%
if do_rfi_round_2:
    filt_data = filters.rms_rfi_filter(rms_data, threshold=1.9, nsamples_strategy=NsamplesStrategy.FLAGGED_NSAMPLES_UNIFORM)
    filt_data_alan = filters.rms_rfi_filter(rms_data_alan, threshold=1.9)
else:
    filt_data = rms_data
    filt_data_alan = rms_data_alan

# %% [markdown]
# Now, make sure that we flagged exactly the same channels/nights as the C-code

# %%
alanweights= np.genfromtxt("/home/smurray/data4/edges/alans-pipeline/scripts/nightly_weights.txt")
weights= filt_data.flagged_nsamples[0,0] > 0

if raise_unmatching and do_rfi_round_2:
    assert np.sum(weights ^ alanweights.astype(bool))==0
elif compare_alan:
    print("Number of flags differing: ", np.sum(weights ^ alanweights.astype(bool)))

# %%
plots.plot_waterfall(filt_data);

# %% [markdown]
# ### Inspect the noise distribution at this stage

# %%
nsamples_strategy = NsamplesStrategy.FLAGGED_NSAMPLES_UNIFORM
w = get_weights_from_strategy(rms_data, nsamples_strategy)[0]
rms = np.sqrt(np.average(np.square(rms_data.residuals), weights=w, axis=-1))[..., None]

nflagged = np.nansum(np.where(rms_data.flagged_nsamples>0, (rms_data.residuals/rms), -np.inf).flatten()>1.9)
ntot = np.nansum(np.where(rms_data.flagged_nsamples>0, (rms_data.residuals/rms), -np.inf).flatten()>-20)

# %%
plt.hist(np.where(rms_data.flagged_nsamples>0, (rms_data.residuals/rms), np.nan).flatten(), bins=70, density=True);
x = np.linspace(-4, 4, 101)
plt.plot(x, norm.pdf(x))
plt.axvline(1.9, color='k', ls='--')
plt.xlabel("Z Score")
plt.ylabel("PDF")
plt.text(2, 0.4, r"$1.9\sigma$")
plt.text(2.5, 0.05, rf"{nflagged*100/ntot:.1}\% \\ data cut")
# Out:
# Text(2.5, 0.05, '3e+00\\% \\\\ data cut')

# %% [markdown]
# ### Average all nights

# %%
avg_data = average_over_times(
    filt_data, use_resids=True, nsamples_strategy=NsamplesStrategy.FLAGGED_NSAMPLES_UNIFORM
)
avg_data_alan = average_over_times(
    filt_data_alan, use_resids=True, nsamples_strategy=NsamplesStrategy.FLAGGED_NSAMPLES_UNIFORM
)
# Out:
# /data7/smurray/edges/projects_with_nive/edges-bowman2018-pipeline/.venv/lib/python3.11/site-packages/edges/averaging/lstbin.py:101: RuntimeWarning: invalid value encountered in divide
#   mean_resids = sum_resids / ntot

# %% [markdown]
# ### Last RFI Filter

# %%
avg_data = add_model(avg_data, model=mdl.Polynomial(offset=-2.5, n_terms=7, transform=mdl.ScaleTransform(scale=75.0)), nsamples_strategy=NsamplesStrategy.FLAGGED_NSAMPLES_UNIFORM)
avg_data_alan = add_model(avg_data_alan, model=mdl.Polynomial(offset=-2.5, n_terms=7, transform=mdl.ScaleTransform(scale=75.0)), nsamples_strategy=NsamplesStrategy.FLAGGED_NSAMPLES)

# %%
if do_rfi_round_3:
    final_data = filters.rms_rfi_filter(avg_data, threshold=1.9)
    final_data_alan = filters.rms_rfi_filter(avg_data_alan, threshold=1.9)
else:
    final_data = avg_data
    final_data_alan = avg_data_alan

# %%
final_data = add_model(final_data, model=mdl.LinLog(n_terms=5))
final_data_alan = add_model(final_data_alan, model=mdl.LinLog(n_terms=5))

# %% [markdown]
# ## Inspect Final Results

# %%
alan_fl = f"{alandir}/final_average_latest.txt"
alan = np.genfromtxt(alan_fl, usecols=(1, 3, 6, 9, 12), names=('freq', 'tant', 'model', 'resid', 'weight'))

# %%
linlog = mdl.LinLog(n_terms=5).at(x=final_data.freqs)

# %%
ourfit = linlog.fit(ydata=final_data.data[0,0,0], weights=final_data.flagged_nsamples[0,0,0]>0)
ourfit_alan = linlog.fit(ydata=final_data_alan.data[0,0,0], weights=final_data_alan.flagged_nsamples[0,0,0]>0)
alfit = linlog.fit(ydata=alan['tant'], weights=alan['weight'])

# %%
def plot_final_data(final_data, label: str):
    fig, ax = plt.subplots(3, 1, sharex=True, figsize=(10, 8), constrained_layout=True)

    ax[0].plot(final_data.freqs, np.where(final_data.flagged_nsamples[0,0,0]>0, final_data.data[0,0,0], np.nan), label=label)
    ax[0].plot(final_data.freqs, np.where(alan['weight']>0, alan['tant'], np.nan), label='C-code', ls='--')
    ax[0].legend()
    ax[0].text(0.95, 0.9, "Spectrum", transform=ax[0].transAxes, ha='right', fontweight='bold')

    for i in range(3):
        ax[i].set_ylabel("Temperature [K]")
        
    ttmin = data.times.min().datetime.timetuple()
    ttmax = data.times.max().datetime.timetuple()

    fig.suptitle(f"Final Averaged Spectrum: {rms_data.ntimes} days [{ttmin.tm_year}:{ttmin.tm_yday:>03} -- {ttmax.tm_year}:{ttmax.tm_yday:>03}]")

    ax[1].plot(final_data.freqs, np.where(final_data.flagged_nsamples[0,0,0]>0, ourfit.residual, np.nan))

    ax[1].plot(final_data.freqs, np.where(final_data.flagged_nsamples[0,0,0]>0, alfit.residual, np.nan), ls='--')
    ax[1].text(0.95, 0.9, "FG Residuals (LinLog, 5-term)", transform=ax[1].transAxes, ha='right', fontweight='bold')


    ax[2].plot(final_data.freqs, np.where(final_data.flagged_nsamples[0,0,0]>0, final_data.data[0,0,0] - alan['tant'], np.nan), color='b')
    ax[2].set_xlabel("Frequency [MHz]")
    ax[2].text(0.95, 0.9, "Absolute Difference between pipelines", transform=ax[2].transAxes, ha='right', fontweight='bold');

# %%
plot_final_data(final_data, 'edges-analysis')

# %%
plot_final_data(final_data_alan, 'edges-analysis w/ final nights from B18')

# %% [markdown]
# We ensure that we have all the same flags as the C-code:

# %%
if raise_unmatching:
    assert np.sum((final_data.flagged_nsamples > 0) ^ alan['weight'].astype(bool))==0
elif compare_alan:
    print("Unmatched flags: ", np.sum((final_data.flagged_nsamples > 0) ^ alan['weight'].astype(bool)))

# %%
plt.plot(final_data.freqs, final_data.flagged_nsamples[0,0,0])
plt.xlabel("Frequency [MHz]")
plt.ylabel("Nsamples");

# %% [markdown]
# ## Write out the data

# %%
final_data.write_gsh5(gathered_days_file.parent / "averaged_spectrum.gsh5");
#           4101737.4104338 , 3852564.92641711, 4128982.82809183,
#           3981123.63458089, 3937389.49884403, 4111134.9384505 ,
#           4004098.97758375, 4123292.86855032, 4160875.08672645,
#           4088772.62349491, 3620498.86096718, 3538153.52006461,
#           3500489.04739834, 3854231.83982888, 3662054.11309314,
#           4003801.93158633, 4112849.67895357, 3664298.67087545,
#           3643791.08721896, 3488046.60537404, 1615090.9248277 ,
#           2613239.94307805, 3039417.24613565, 2413987.14408104,
#           2960879.70464847, 2466496.76834313, 2204151.14076495,
#           2026811.71598268, 1865017.88583955, 2152408.04144019,
#           2524637.31952271, 1871875.41647408,  411821.79686289,
#           1625405.38991036, 2769949.62389849, 2599201.12029742,
#           1103081.06861176, 2592335.68067309, 1143209.03870218,
#                 0.        ,       0.        ]]]]), loads=('ant',), flags={'rms_rfi_filter': GSFlag(flags=array([[[[False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#            True, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False]]]]), axes=('load', 'pol', 'time', 'freq'), history=!!python/tuple []
# , filename=None)}, history=!!python/tuple
# - function: read_acq_to_gsdata
#   message: Read from ACQ file
#   parameters:
#     path:
#     - 'tag:yaml.org,2002:python/object/apply:pathlib.PosixPath: [ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''/''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''data5''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''edges''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''data''),
#       ScalarNode(tag=''tag:yaml.org,2002:str'', value=''2014_February_Boolardy''),
#       ScalarNode(tag=''tag:yaml.org,2002:str'', value=''mro''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''low''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''2016''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''2016_250_02.acq'')]'
#   timestamp: '2025-09-19T16:46:31.432746'
#   versions:
#     astropy: 7.1.0
#     numpy: 2.3.2
#     pygsdata: 0.2.3
# - function: select_lsts
#   message: ''
#   parameters:
#     gha: true
#     load: all
#     lst_range:
#     - 6.0
#     - 18.0
#   timestamp: '2025-11-17T11:58:19.286687'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: aux_filter
#   message: ''
#   parameters:
#     maxima:
#       adcmax: 0.35
#     minima: {}
#   timestamp: '2025-11-17T11:58:21.847257'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: power_percent_filter
#   message: ''
#   parameters:
#     max_threshold: 3
#     min_threshold: 0.7
#   timestamp: '2025-11-17T11:58:56.471020'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: dicke_calibration
#   message: ''
#   parameters: {}
#   timestamp: '2025-11-17T11:58:57.250526'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: approximate_temperature
#   message: ''
#   parameters:
#     tload: 300
#     tns: 1000
#   timestamp: '2025-11-17T11:58:57.456138'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: peak_orbcomm_filter
#   message: ''
#   parameters:
#     threshold: 40.0
#   timestamp: '2025-11-17T11:58:59.851752'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: maxfm_filter
#   message: ''
#   parameters:
#     threshold: 200.0
#   timestamp: '2025-11-17T11:59:01.272255'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: rmsf_filter
#   message: ''
#   parameters:
#     freq_range:
#     - 60.0
#     - 80.0
#     threshold: 200.0
#   timestamp: '2025-11-17T11:59:02.573930'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: average_over_times
#   message: ''
#   parameters:
#     nsamples_strategy: 'tag:yaml.org,2002:python/object/apply:edges.averaging.utils.NsamplesStrategy:
#       [ScalarNode(tag=''tag:yaml.org,2002:int'', value=''2'')]'
#     reference_lst: "tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:\
#       \ [(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.coordinates.angles.core.Longitude',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='0')]), ScalarNode(tag='tag:yaml.org,2002:binary', value='Yg==\\n')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='state'), SequenceNode(tag='tag:yaml.org,2002:python/tuple',\
#       \ value=[SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1'), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[]),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object/apply:numpy.dtype', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='args'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='f8'), ScalarNode(tag='tag:yaml.org,2002:bool', value='false'), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='3'), ScalarNode(tag='tag:yaml.org,2002:str', value='<'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:null', value='null'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:int', value='-1'), ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='-1'), ScalarNode(tag='tag:yaml.org,2002:int', value='0')]))]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='false'), ScalarNode(tag='tag:yaml.org,2002:binary', value='tI1QRm8LF0A=\\\
#       n')]), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_unit'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.Unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='hour angle: angular measurement with 24 in a full circle')), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_format'), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='latex'), ScalarNode(tag='tag:yaml.org,2002:str', value='{}^{h}')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='unicode'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='\u02B0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_names'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='hourangle')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_represents'),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.Unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree: angular measurement 1/360 of full rotation')), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_format'), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='latex'), ScalarNode(tag='tag:yaml.org,2002:str', value='{}^{\\\\circ}')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='unicode'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='\xB0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg'), ScalarNode(tag='tag:yaml.org,2002:str', value='degree')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_represents'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian: angular\
#       \ measurement of the ratio between the length on an arc\\nand its radius')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_format'), MappingNode(tag='tag:yaml.org,2002:map',\
#       \ value=[])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='radian')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:str', value='rad')]))]))])])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_decomposed_cache'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[...])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_powers'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='0.017453292519943295'))])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg')]))])])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_decomposed_cache'),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian: angular\
#       \ measurement of the ratio between the length on an arc\\nand its radius')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_format'), MappingNode(tag='tag:yaml.org,2002:map',\
#       \ value=[])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='radian')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:str', value='rad')]))]))])])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_powers'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='0.2617993877991494'))])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_powers'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='15.0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='hourangle')]))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_wrap_angle'),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.coordinates.angles.core.Angle',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='0')]), ScalarNode(tag='tag:yaml.org,2002:binary', value='Yg==\\n')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='state'), SequenceNode(tag='tag:yaml.org,2002:python/tuple',\
#       \ value=[SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1'), SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[]),\
#       \ MappingNode(tag='tag:yaml.org,2002:python/object/apply:numpy.dtype', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='args'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='f8'), ScalarNode(tag='tag:yaml.org,2002:bool', value='false'), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:python/tuple', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='3'), ScalarNode(tag='tag:yaml.org,2002:str', value='<'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:null', value='null'), ScalarNode(tag='tag:yaml.org,2002:null',\
#       \ value='null'), ScalarNode(tag='tag:yaml.org,2002:int', value='-1'), ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='-1'), ScalarNode(tag='tag:yaml.org,2002:int', value='0')]))]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='false'), ScalarNode(tag='tag:yaml.org,2002:binary', value='AAAAAACAdkA=\\\
#       n')]), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_unit'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.Unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree: angular measurement 1/360 of full rotation')), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_format'), MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='latex'), ScalarNode(tag='tag:yaml.org,2002:str', value='{}^{\\\\circ}')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='unicode'), ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='\xB0'))])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='degree')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg'), ScalarNode(tag='tag:yaml.org,2002:str', value='degree')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_represents'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='_bases'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[MappingNode(tag='tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit',\
#       \ value=[(ScalarNode(tag='tag:yaml.org,2002:str', value='args'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit',\
#       \ value=''), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')]), ScalarNode(tag='tag:yaml.org,2002:bool',\
#       \ value='true')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='state'),\
#       \ MappingNode(tag='tag:yaml.org,2002:map', value=[(ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='__doc__'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian: angular\
#       \ measurement of the ratio between the length on an arc\\nand its radius')),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_format'), MappingNode(tag='tag:yaml.org,2002:map',\
#       \ value=[])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_long_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='radian')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_names'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='rad'), ScalarNode(tag='tag:yaml.org,2002:str', value='radian')])),\
#       \ (ScalarNode(tag='tag:yaml.org,2002:str', value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq',\
#       \ value=[ScalarNode(tag='tag:yaml.org,2002:str', value='rad')]))]))])])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_decomposed_cache'), MappingNode(tag='tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit',\
#       \ value=[...])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_powers'),\
#       \ SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:int',\
#       \ value='1')])), (ScalarNode(tag='tag:yaml.org,2002:str', value='_scale'), ScalarNode(tag='tag:yaml.org,2002:float',\
#       \ value='0.017453292519943295'))])), (ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='_short_names'), SequenceNode(tag='tag:yaml.org,2002:seq', value=[ScalarNode(tag='tag:yaml.org,2002:str',\
#       \ value='deg')]))]))])]))]))])]))]"
#     use_resids: false
#   timestamp: '2025-11-17T11:59:11.238720'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: select_freqs
#   message: ''
#   parameters:
#     freq_range:
#     - 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:
#       [(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.quantity.Quantity'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''Yg==\n'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[]),
#       MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#       value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#       ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]))]), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''AAAAAAAAREA=\n'')]), MappingNode(tag=''tag:yaml.org,2002:map'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_unit''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.PrefixUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz (MHz)'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''MHz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.Unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Frequency'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''Hz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_decomposed_cache''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[...])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_powers''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hz'')]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_decomposed_cache''),
#       MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''MHz'')]))]))])]))]'
#     - 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:
#       [(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.quantity.Quantity'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''Yg==\n'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[]),
#       MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#       value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#       ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]))]), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
#       ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''AAAAAAAAWUA=\n'')]), MappingNode(tag=''tag:yaml.org,2002:map'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_unit''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.PrefixUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz (MHz)'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''MHz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''megaHertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''megahertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.Unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Frequency'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''Hz''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hertz''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''hertz'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_represents''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_decomposed_cache''), MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[...])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_powers''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''Hz'')]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_decomposed_cache''),
#       MappingNode(tag=''tag:yaml.org,2002:python/object:astropy.units.core.CompositeUnit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_bases''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[MappingNode(tag=''tag:yaml.org,2002:python/object/apply:astropy.units.core._recreate_irreducible_unit'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.core.IrreducibleUnit'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''state''), MappingNode(tag=''tag:yaml.org,2002:map'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''__doc__''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second:
#       base unit of time in SI.'')), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_format''),
#       MappingNode(tag=''tag:yaml.org,2002:map'', value=[])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_long_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''second'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_names''),
#       SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''s''), ScalarNode(tag=''tag:yaml.org,2002:str'', value=''second'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''s'')]))]))])])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_powers''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1'')])), (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''_scale''),
#       ScalarNode(tag=''tag:yaml.org,2002:float'', value=''1000000.0''))])), (ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''_short_names''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''MHz'')]))]))])]))]'
#   timestamp: '2025-11-17T11:59:11.371944'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: gauss_smooth
#   message: ''
#   parameters:
#     decimate_at: 0
#     flag_threshold: 0.25
#     maintain_flags: 1
#     size: 8
#     use_nsamples: true
#   timestamp: '2025-11-17T11:59:13.036011'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: select_freqs
#   message: ''
#   parameters:
#     freq_range: !!python/tuple
#     - 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:
#       [(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:astropy.units.quantity.Quantity'',
#       value=''''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''Yg==\n'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[]),
#       MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'', value=[(ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'', value=[ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''),
# ...
#       meta:
#         beam_file: /data4/nmahesh/edges/code_from_alan_org/newniv.txt
#         f_high: 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray.scalar:
#           [MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'',
#           value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#           value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'',
#           value=''false''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])),
#           (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#           value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#           value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#           ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#           value=''null''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''),
#           ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#           value=''0'')]))]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''AAAAAAAAWUA=\n'')]'
#         f_low: 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray.scalar:
#           [MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'',
#           value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#           value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'',
#           value=''false''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])),
#           (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#           value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#           value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#           ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#           value=''null''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''),
#           ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#           value=''0'')]))]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''AAAAAAAAREA=\n'')]'
#         index_model: ConstantIndex(index=2.5)
#         normalize_beam: false
#         rotation_from_north: 90.0
#         simulator: feko
#         sky_model: Haslam408AllNoh
#       reference_frequency: 75.0
#     cut_to_data_lsts: false
#     freq_model:
#       _transform:
#         shift: 75.0
#       basis_scaler: null
#       data_transform: {}
#       n_terms: 31
#       parameters: null
#       period: 74.39999999999999
#       xtransform:
#         shift: 75.0
#     integrate_before_ratio: true
#     lsts: 'tag:yaml.org,2002:python/object/apply:numpy._core.multiarray._reconstruct:
#       [(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:python/name:numpy.ndarray'', value=''''),
#       SequenceNode(tag=''tag:yaml.org,2002:python/tuple'', value=[ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''0'')]), ScalarNode(tag=''tag:yaml.org,2002:binary'', value=''Yg==\n'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''1''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''845'')]), MappingNode(tag=''tag:yaml.org,2002:python/object/apply:numpy.dtype'',
#       value=[(ScalarNode(tag=''tag:yaml.org,2002:str'', value=''args''), SequenceNode(tag=''tag:yaml.org,2002:seq'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:str'', value=''f8''), ScalarNode(tag=''tag:yaml.org,2002:bool'',
#       value=''false''), ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''true'')])),
#       (ScalarNode(tag=''tag:yaml.org,2002:str'', value=''state''), SequenceNode(tag=''tag:yaml.org,2002:python/tuple'',
#       value=[ScalarNode(tag=''tag:yaml.org,2002:int'', value=''3''), ScalarNode(tag=''tag:yaml.org,2002:str'',
#       value=''<''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'',
#       value=''null''), ScalarNode(tag=''tag:yaml.org,2002:null'', value=''null''),
#       ScalarNode(tag=''tag:yaml.org,2002:int'', value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'',
#       value=''-1''), ScalarNode(tag=''tag:yaml.org,2002:int'', value=''0'')]))]),
#       ScalarNode(tag=''tag:yaml.org,2002:bool'', value=''false''), ScalarNode(tag=''tag:yaml.org,2002:binary'',
#       value=''\n7XkA7z9g ...
#     resample_beam_lsts: true
#   timestamp: '2025-12-11T11:41:27.751158'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: add_model
#   message: ''
#   parameters:
#     model:
#       _transform:
#         scale: 75.0
#       basis_scaler: null
#       data_transform: {}
#       f_center: 75.0
#       n_terms: 3
#       parameters: null
#       spectral_index: -2.5
#       with_cmb: false
#       xtransform:
#         scale: 75.0
#     nsamples_strategy: 'tag:yaml.org,2002:python/object/apply:edges.averaging.utils.NsamplesStrategy:
#       [ScalarNode(tag=''tag:yaml.org,2002:int'', value=''2'')]'
#   timestamp: '2025-12-11T11:41:28.281672'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: gauss_smooth
#   message: ''
#   parameters:
#     decimate_at: 0
#     maintain_flags: 9
#     nsmooth: 2
#     size: 8
#     use_nsamples: false
#     use_residuals: true
#   timestamp: '2025-12-11T11:41:29.024364'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: concat
#   message: ''
#   parameters: {}
#   timestamp: '2025-12-11T11:43:35.125296'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: add_model
#   message: ''
#   parameters:
#     model:
#       _transform:
#         scale: 75.0
#       basis_scaler: null
#       data_transform: {}
#       f_center: 75.0
#       n_terms: 5
#       parameters: null
#       spectral_index: -2.55
#       with_cmb: false
#       xtransform:
#         scale: 75.0
#     nsamples_strategy: &id001 !!python/object/apply:edges.averaging.utils.NsamplesStrategy
#     - 2
#   timestamp: '2025-12-11T11:43:43.730577'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: prune_flagged_integrations
#   message: ''
#   parameters: {}
#   timestamp: '2025-12-11T11:43:44.167362'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: average_over_times
#   message: ''
#   parameters:
#     nsamples_strategy: *id001
#     use_resids: true
#   timestamp: '2025-12-11T11:43:45.565504'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: add_model
#   message: ''
#   parameters:
#     model:
#       _transform:
#         scale: 75.0
#       basis_scaler: null
#       data_transform: {}
#       n_terms: 7
#       offset: -2.5
#       parameters: null
#       spacing: 1.0
#       xtransform:
#         scale: 75.0
#     nsamples_strategy: !!python/object/apply:edges.averaging.utils.NsamplesStrategy
#     - 0
#   timestamp: '2025-12-11T11:43:45.691185'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# - function: add_model
#   message: ''
#   parameters:
#     model:
#       _transform:
#         scale: 75.0
#       basis_scaler: null
#       beta: -2.5
#       data_transform: {}
#       f_center: 75.0
#       n_terms: 5
#       parameters: null
#       with_cmb: false
#       xtransform:
#         scale: 75.0
#   timestamp: '2025-12-11T11:43:45.832983'
#   versions:
#     astropy: 7.1.1
#     numpy: 2.3.4
#     pygsdata: 0.2.3
# , residuals=array([[[[-4.92549600e+03, -4.82887998e+03, -4.73489378e+03,
#           -2.33727927e-02,  8.03329906e-02,  7.56753059e-02,
#            2.31976437e-02,  3.32990534e-02,  7.39213317e-03,
#            1.25583710e-02,  7.39942274e-03, -7.06189586e-02,
