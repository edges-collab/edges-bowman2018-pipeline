# %% [markdown]
# # Look at the synthesis of flags over all nights

# %%
from pygsdata import GSData

# %%
pth = "output-notebooks/2016-260.pre-rfi.gsh5"

# %%
data = GSData.from_file(pth)

# %%
data.flags
# Out:
# {'empty_lsts': GSFlag(flags=array([False]), axes=('time',), history=!!python/tuple []
#  , filename=None)}
